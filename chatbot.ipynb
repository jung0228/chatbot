# %%
print("안녕하세요? 당신의 옷 선택을 도와줄 챗봇입니다!")
print("당신에게 몇가지 질문을 드릴테니 선택지를 골라주세요.")
# Out:
# 안녕하세요? 당신의 옷 선택을 도와줄 챗봇입니다!
# 당신에게 몇가지 질문을 드릴테니 선택지를 골라주세요.

# %%
print("우선 상의부터 골라드리겠습니다.")
# Out:
# 우선 상의부터 골라드리겠습니다.

# %%
weather = int(input("현재 무슨 계절인가요?? (봄/여름) 인가요? (가을/겨울)인가요? \n (봄/여름)은 1번을 (가을/겨울)은 2번을 눌러주세요."))

# %%
style = int(input("댄디와 캐주얼 중에서 어떤 스타일을 좋아하시나요? 댄디는 1번 캐주얼은 2번을 눌러주세요."))

# %%
outer = int(input("겉옷을 즐겨입으시나요? yes:1, no:2"))

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

if (weather == 1):
  print("현재 날씨가 따뜻한가보네요... 덥지 않은 옷을 골라드리겠습니다!")
  if (style == 1):
    print("또한 댄디한 스타일을 좋아하시나보네요...")
    if (outer == 1):
      print("그리고 겉옷을 잘 입으시나보네요...")
      img1 = mpimg.imread('상의1.png')
    else:
      print("그리고 겉옷은 잘 안 입으시나보네요...")
      img1 = mpimg.imread('상의2.png')
  else:
    print("또한 캐주얼한 스타일을 좋아하시나보네요...")
    if (outer == 1):
      print("그리고 겉옷을 잘 입으시나보네요...")
      img1 = mpimg.imread('상의3.png')
    else:
      print("그리고 겉옷은 잘 안 입으시나보네요...")
      img1 = mpimg.imread('상의4.png')
else:
  print("현재 날씨가 쌀쌀한가보네요... 따뜻하게 입혀드리겠습니다!")
  if(style == 1):
    print("또한 댄디한 스타일을 좋아하시나보네요...")
    if (outer == 1):
      print("그리고 겉옷을 잘 입으시나보네요...")
      img1 = mpimg.imread('상의5.png')
    else:
      print("그리고 겉옷은 잘 안 입으시나보네요...")
      img1 = mpimg.imread('상의6.png')
  else:
    print("또한 캐주얼한 스타일을 좋아하시나보네요...")
    if (outer == 1):
      print("그리고 겉옷을 잘 입으시나보네요...")
      img1 = mpimg.imread('상의7.png')
    else:
      print("그리고 겉옷은 잘 안 입으시나보네요...")
      img1 = mpimg.imread('상의8.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/jhw/Desktop/팀플4사진/chatbot.ipynb 셀 6 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/Users/jhw/Desktop/%E1%84%90%E1%85%B5%E1%86%B7%E1%84%91%E1%85%B3%E1%86%AF4%E1%84%89%E1%85%A1%E1%84%8C%E1%85%B5%E1%86%AB/chatbot.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> import matplotlib.pyplot as plt
#       <a href='vscode-notebook-cell:/Users/jhw/Desktop/%E1%84%90%E1%85%B5%E1%86%B7%E1%84%91%E1%85%B3%E1%86%AF4%E1%84%89%E1%85%A1%E1%84%8C%E1%85%B5%E1%86%AB/chatbot.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> import matplotlib.image as mpimg
# ----> <a href='vscode-notebook-cell:/Users/jhw/Desktop/%E1%84%90%E1%85%B5%E1%86%B7%E1%84%91%E1%85%B3%E1%86%AF4%E1%84%89%E1%85%A1%E1%84%8C%E1%85%B5%E1%86%AB/chatbot.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a> if (weather == 1):
# ...

# %%
print("당신에게 어울리는 상의를 골라드리겠습니다...")
plt.imshow(img1)
plt.show()
# Out:
# 당신에게 어울리는 상의를 골라드리겠습니다...

# %%
print("하의도 추천드리겠습니다!")
size = int(input("평소에 크게 입는 것을 좋아하시나요? 크게 입는다: 1, 아니다: 2"))
# Out:
# 하의도 추천드리겠습니다!

# %%
if (weather == 1):
  if (style == 1):
    if (size == 1):
      img2 = mpimg.imread('바지1.png')
    else:
      img2 = mpimg.imread('바지2.png')
  else:
    if (size == 1):
      img2 = mpimg.imread('바지3.png')
    else:
      img2 = mpimg.imread('바지4.png')
else:
  if(style == 1):
    if (size == 1):
      img2 = mpimg.imread('바지5.png')
    else:
      img2 = mpimg.imread('바지6.png')
  else:
    if (size == 1):
      img2 = mpimg.imread('바지7.png')
    else:
      img2 = mpimg.imread('바지8.png')

# %%
print("당신에게 좋아할만한 바지도 골라드리겠습니다...")
plt.imshow(img2)
plt.show()
# Out:
# 당신에게 좋아할만한 바지도 골라드리겠습니다...

# %%
print("신발은 어떤게 좋을까요?")
free = int(input("편한 신발을 좋아하시나요? 그렇다: 1, 그렇지 않다: 2"))
# Out:
# 신발은 어떤게 좋을까요?

# %%
if (weather == 1):
  if (style == 1):
    if (free == 1):
      img3 = mpimg.imread('신발1.png')
    else:
      img3 = mpimg.imread('신발2.png')
  else:
    if (free == 1):
      img3 = mpimg.imread('신발3.png')
    else:
      img3 = mpimg.imread('신발4.png')
else:
  if(style == 1):
    if (free == 1):
      img3 = mpimg.imread('신발5.png')
    else:
      img3 = mpimg.imread('신발6.png')
  else:
    if (free == 1):
      img3 = mpimg.imread('신발7.png')
    else:
      img3 = mpimg.imread('신발8.png')

# %%
print("이 신발 마음에 드시나요?...")
plt.imshow(img3)
plt.show()
# Out:
# 이 신발 마음에 드시나요?...

# %%
print("당신이 오늘 입을 옷을 추천드리겠습니다.")

plt.imshow(img1)
plt.show()

plt.imshow(img2)
plt.show()

plt.imshow(img3)
plt.show()

print("좋은 하루 되세요~")
# Out:
# 당신이 오늘 입을 옷을 추천드리겠습니다.
# 마음에 드시나요?
